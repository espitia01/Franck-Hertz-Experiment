# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
data = pd.read_csv("HgRerun.csv")

# %%
data.head()
# Out:
#    Time (s) Run #1  Current (A) Run #1  Voltage (V) Run #1  Time (s) Run #2  \
# 0             0.00        1.868000e-14                -0.3             0.00
# 1             0.05        1.794000e-14                -0.3             0.05
# 2             0.10        8.179000e-15                -0.3             0.10
# 3             0.15        1.001000e-14                -0.3             0.15
# 4             0.20        8.179000e-15                -0.3             0.20
#
#    Current (A) Run #2  Voltage (V) Run #2  Time (s) Run #3  \
# 0       -9.546000e-14                -0.3             0.00
# 1       -9.424000e-14                -0.3             0.05
# 2       -1.061000e-13                -0.3             0.10
# 3       -1.067000e-13                -0.3             0.15
# 4       -1.049000e-13                -0.3             0.20
#
#    Current (A) Run #3  Voltage (V) Run #3  Time (s) Run #4  ...  \
# 0        1.953000e-12                -0.3             0.00  ...
# ...

# %%
#Data 1
current_1 = data["Current (A) Run #1"].to_numpy()
voltage_1 = data["Voltage (V) Run #1"].to_numpy()

#Data 2
current_2 = data["Current (A) Run #2"].to_numpy()
voltage_2 = data["Voltage (V) Run #2"].to_numpy()

#Data 3
current_3 = data["Current (A) Run #3"].to_numpy()
voltage_3 = data["Voltage (V) Run #3"].to_numpy()
#Data 4
current_4 = data["Current (A) Run #4"].to_numpy()
voltage_4 = data["Voltage (V) Run #4"].to_numpy()

#Data 5
current_5 = data["Current (A) Run #5"].to_numpy()
voltage_5 = data["Voltage (V) Run #5"].to_numpy()

#Data 6
current_6 = data["Current (A) Run #6"].to_numpy()
voltage_6 = data["Voltage (V) Run #6"].to_numpy()

#Data 7
current_7 = data["Current (A) Run #7"].to_numpy()
voltage_7 = data["Voltage (V) Run #7"].to_numpy()

#Data 8
current_8 = data["Current (A) Run #8"].to_numpy()
voltage_8 = data["Voltage (V) Run #8"].to_numpy()

#Data 9
current_9 = data["Current (A) Run #9"].to_numpy()
voltage_9 = data["Voltage (V) Run #9"].to_numpy()

# %%
plt.plot(voltage_1, current_1, label="Trial 1")
plt.plot(voltage_2, current_2, label="Trial 2")
plt.plot(voltage_3, current_3, label="Trial 3")
plt.plot(voltage_4, current_4, label="Trial 4")
plt.plot(voltage_5, current_5, label="Trial 5")
plt.plot(voltage_6, current_6, label="Trial 6")
plt.plot(voltage_7, current_7, label="Trial 7")
plt.plot(voltage_8, current_8, label="Trial 8")
plt.plot(voltage_9, current_9, label="Trial 9")
plt.legend()
plt.title("Current vs Voltage")
plt.xlabel("$V_{acc}$ (V)")
plt.ylabel("$A$ (A)")
# Out:
# Text(0, 0.5, '$A$ (A)')
